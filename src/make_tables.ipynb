# %%
from make_table_helpers import build_theme_table  # <- save the function above in my_ref_utils.py

tbl = build_theme_table(
    zip_path="../data/final/enhanced_ref_data.zip",
    extract_dir="../data/final/extracted",
    output_csv="../tables/theme_statistics.csv",
    column_aliases={
        # Optional: make the resolver prefer your exact names first
        "theme":  ["topic1_theme_long"],
        "topic1": ["topic1_name"],
    },
)
tbl
# Out:
#     Theme Name  Number of ICS            Modal Topic  \
# 0       Cancer             90          Cancer Treat.
# 1      Culture            988  Curation & Engagement
# 2    Education            648               Teaching
# 3  Environment            607           Food Systems
# 4       Health           1444          Mental Health
# 5      Society           1489        Crime & Justice
# 6   Technology           1095  Appl. Physics & Chem.
#
#                                            Modal UoA Modal Panel  \
# 0                                  Clinical Medicine           A
# 1                    English Language and Literature           D
# 2                                          Education           C
# 3                                Biological Sciences           A
# 4  Allied Health Professions, Dentistry, Nursing ...           A
# 5                    Business and Management Studies           C
# 6                                        Engineering           B
#
# ...
