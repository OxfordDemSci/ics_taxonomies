# %%
import pandas as pd
from make_figure_helpers import make_weight_plot, plot_heatmap_mds_K7, visualize_topic_models

# %%
make_weight_plot()
# Out:
# 0.4463134727244144

# %%
#visualize_topic_models()

# %%
results = plot_heatmap_mds_K7()
print("Average silhouette:", results["silhouette_avg"])
# Out:
# Average silhouette: 0.14269560226948333
